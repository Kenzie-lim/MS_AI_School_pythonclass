# %%
print("Hello Python")
# Out:
# Hello Python

# %%
print("안녕하세요")
# Out:
# 안녕하세요

# %%
print("수정 테스트를 해보겠습니다")
# Out:
# 수정 테스트를 해보겠습니다

# %% [markdown]
# 깃헙에 로컬에서 작업한 내용을 올려보자

# %%
print("I am Kenzie Lim. Nice to meet you")
# Out:
# I am Kenzie Lim. Nice to meet you

# %%
# Out:
# 임경아입니다. 반가워요.
