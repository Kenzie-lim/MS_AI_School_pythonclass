# %%
pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.4.0-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Downloading numpy-2.4.0-cp311-cp311-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/12.6 MB 1.7 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/12.6 MB 5.8 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/12.6 MB 7.0 MB/s eta 0:00:02
#    --- ------------------------------------ 1.2/12.6 MB 8.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/12.6 MB 9.2 MB/s eta 0:00:02
#    ------ --------------------------------- 2.0/12.6 MB 9.1 MB/s eta 0:00:02
#    ------- -------------------------------- 2.4/12.6 MB 9.6 MB/s eta 0:00:02
#    -------- ------------------------------- 2.8/12.6 MB 10.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.2/12.6 MB 10.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.6/12.6 MB 10.0 MB/s eta 0:00:01
#    ------------ --------------------------- 4.0/12.6 MB 10.3 MB/s eta 0:00:01
#    -------------- ------------------------- 4.5/12.6 MB 10.6 MB/s eta 0:00:01
#    --------------- ------------------------ 4.9/12.6 MB 10.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.3/12.6 MB 10.5 MB/s eta 0:00:01
#    ------------------ --------------------- 5.7/12.6 MB 10.7 MB/s eta 0:00:01
#    ------------------- -------------------- 6.1/12.6 MB 10.6 MB/s eta 0:00:01
#    -------------------- ------------------- 6.6/12.6 MB 10.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.9/12.6 MB 10.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.4/12.6 MB 10.7 MB/s eta 0:00:01
#    ------------------------ --------------- 7.7/12.6 MB 10.7 MB/s eta 0:00:01
#    ------------------------- -------------- 8.0/12.6 MB 10.6 MB/s eta 0:00:01
#    -------------------------- ------------- 8.3/12.6 MB 10.6 MB/s eta 0:00:01
#    --------------------------- ------------ 8.7/12.6 MB 10.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.1/12.6 MB 10.6 MB/s eta 0:00:01
#    ------------------------------ --------- 9.5/12.6 MB 10.7 MB/s eta 0:00:01
#    ------------------------------- -------- 9.9/12.6 MB 10.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.3/12.6 MB 11.1 MB/s eta 0:00:01
#    --------------------------------- ------ 10.6/12.6 MB 10.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.1/12.6 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------ --- 11.6/12.6 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------- -- 11.9/12.6 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------  12.4/12.6 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 10.9 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.4.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.3-cp311-cp311-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/11.3 MB 8.6 MB/s eta 0:00:02
#    -- ------------------------------------- 0.7/11.3 MB 10.7 MB/s eta 0:00:01
#    --- ------------------------------------ 1.1/11.3 MB 11.3 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.4/11.3 MB 10.1 MB/s eta 0:00:01
#    ------ --------------------------------- 1.8/11.3 MB 10.5 MB/s eta 0:00:01
#    ------- -------------------------------- 2.2/11.3 MB 11.0 MB/s eta 0:00:01
#    --------- ------------------------------ 2.6/11.3 MB 10.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.0/11.3 MB 10.7 MB/s eta 0:00:01
#    ------------ --------------------------- 3.4/11.3 MB 10.9 MB/s eta 0:00:01
#    ------------- -------------------------- 3.8/11.3 MB 11.1 MB/s eta 0:00:01
#    -------------- ------------------------- 4.2/11.3 MB 10.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.6/11.3 MB 11.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.1/11.3 MB 11.2 MB/s eta 0:00:01
#    ------------------- -------------------- 5.5/11.3 MB 11.3 MB/s eta 0:00:01
#    -------------------- ------------------- 5.9/11.3 MB 11.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.3/11.3 MB 11.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.5/11.3 MB 11.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.5/11.3 MB 10.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/11.3 MB 10.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.7/11.3 MB 9.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.8/11.3 MB 9.2 MB/s eta 0:00:01
#    ------------------------ --------------- 6.9/11.3 MB 8.9 MB/s eta 0:00:01
#    ------------------------- -------------- 7.2/11.3 MB 8.8 MB/s eta 0:00:01
#    -------------------------- ------------- 7.5/11.3 MB 8.9 MB/s eta 0:00:01
#    --------------------------- ------------ 7.9/11.3 MB 8.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.4/11.3 MB 9.1 MB/s eta 0:00:01
#    ------------------------------ --------- 8.7/11.3 MB 9.2 MB/s eta 0:00:01
#    -------------------------------- ------- 9.2/11.3 MB 9.2 MB/s eta 0:00:01
#    --------------------------------- ------ 9.6/11.3 MB 9.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.0/11.3 MB 9.4 MB/s eta 0:00:01
#    ------------------------------------ --- 10.4/11.3 MB 9.5 MB/s eta 0:00:01
#    -------------------------------------- - 10.8/11.3 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 9.2 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#    ---------------------------------------- 0.0/509.2 kB ? eta -:--:--
#    -------------------------------- ------ 419.8/509.2 kB 13.2 MB/s eta 0:00:01
#    ---------------------------------------- 509.2/509.2 kB 7.9 MB/s eta 0:00:00
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
#    ---------------------------------------- 0.0/348.5 kB ? eta -:--:--
#    --------------------------------------  348.2/348.5 kB 10.9 MB/s eta 0:00:01
#    --------------------------------------- 348.5/348.5 kB 10.9 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.3.3 pytz-2025.2 tzdata-2025.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import numpy as np

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
pd.read_excel("KODEX_대만테크고배당다우존스_20260105.xls").head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 pd.read_excel("KODEX_대만테크고배당다우존스_20260105.xls").head()
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_xlrd.py:45, in XlrdReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#      33 """
#      34 Reader using xlrd engine.
#      35
#    (...)     42     Arbitrary keyword arguments passed to excel engine.
#      43 """
#      44 err_msg = "Install xlrd >= 2.0.1 for xls Excel support"
# ---> 45 import_optional_dependency("xlrd", extra=err_msg)
#      46 super().__init__(
#      47     filepath_or_buffer,
#      48     storage_options=storage_options,
#      49     engine_kwargs=engine_kwargs,
#      50 )
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'xlrd'. Install xlrd >= 2.0.1 for xls Excel support Use pip or conda to install xlrd.

# %%
df = pd.read_csv('heroes.csv')

# %%
df
# Out:
#       이름  나이     직업     국적    키            재산
# 0   아이언맨  58    CEO     미국  174  1.150000e+10
# 1     토르  45      신  아스가르드  190           NaN
# 2  스파이더맨  18   고등학생     미국  177  6.000000e+02
# 3   원더우먼  27     공주  데미스키라  178           NaN
# 4     헐크  33  핵물리학자     미국  270  1.000000e+09
# 5   캡틴마블  25    파일럿     미국  170  3.400000e+08
# 6  블랙위도우  32    스파이    러시아  170  5.000000e+07

# %%
pd.options.display.float_format = '{:.0f}'.format

# %%
pd.options.display.float_format = '{:.0f}'.format

# %%
df
# Out:
#       이름  나이     직업     국적    키          재산
# 0   아이언맨  58    CEO     미국  174 11500000000
# 1     토르  45      신  아스가르드  190         NaN
# 2  스파이더맨  18   고등학생     미국  177         600
# 3   원더우먼  27     공주  데미스키라  178         NaN
# 4     헐크  33  핵물리학자     미국  270  1000000000
# 5   캡틴마블  25    파일럿     미국  170   340000000
# 6  블랙위도우  32    스파이    러시아  170    50000000

# %%
df.sample(2)
# Out:
#       이름  나이   직업   국적    키          재산
# 0   아이언맨  58  CEO   미국  174 11500000000
# 6  블랙위도우  32  스파이  러시아  170    50000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      7 non-null      object
#  1   나이      7 non-null      int64
#  2   직업      7 non-null      object
#  3   국적      7 non-null      object
#  4   키       7 non-null      int64
#  5   재산      5 non-null      float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 468.0+ bytes

# %%
df.describe()
# Out:
#        나이   키          재산
# count   7   7           5
# mean   34 190  2578000120
# std    13  36  5003440739
# min    18 170         600
# 25%    26 172    50000000
# 50%    32 177   340000000
# 75%    39 184  1000000000
# max    58 270 11500000000

# %%
df.head()
# Out:
#       이름  나이     직업     국적    키          재산
# 0   아이언맨  58    CEO     미국  174 11500000000
# 1     토르  45      신  아스가르드  190         NaN
# 2  스파이더맨  18   고등학생     미국  177         600
# 3   원더우먼  27     공주  데미스키라  178         NaN
# 4     헐크  33  핵물리학자     미국  270  1000000000

# %%
df['국적'].unique()
# Out:
# array(['미국', '아스가르드', '데미스키라', '러시아'], dtype=object)

# %%
df['국적'].value_counts()
# Out:
# 국적
# 미국       4
# 아스가르드    1
# 데미스키라    1
# 러시아      1
# Name: count, dtype: int64

# %%
df['나이'].nsmallest(n=3)
# Out:
# 2    18
# 5    25
# 3    27
# Name: 나이, dtype: int64

# %%
df.nsmallest(columns = '나이', n=2)
# Out:
#       이름  나이    직업  국적    키        재산
# 2  스파이더맨  18  고등학생  미국  177       600
# 5   캡틴마블  25   파일럿  미국  170 340000000

# %%
# mission
# 키가 큰 순서대로 7명을 정렬하라

df.nlargest(columns='키', n=7)
# Out:
#       이름  나이     직업     국적    키          재산
# 4     헐크  33  핵물리학자     미국  270  1000000000
# 1     토르  45      신  아스가르드  190         NaN
# 3   원더우먼  27     공주  데미스키라  178         NaN
# 2  스파이더맨  18   고등학생     미국  177         600
# 0   아이언맨  58    CEO     미국  174 11500000000
# 5   캡틴마블  25    파일럿     미국  170   340000000
# 6  블랙위도우  32    스파이    러시아  170    50000000

# %%
# 내가 원하는 데이터만 선별해서 해보기

# %%
type(df[['이름','국적']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['이름'][:5]
#판다스는 결국 1,2차원 array입니다.
# Out:
# 0     아이언맨
# 1       토르
# 2    스파이더맨
# 3     원더우먼
# 4       헐크
# Name: 이름, dtype: object

# %%
df[:3]['이름']
# Out:
# 0     아이언맨
# 1       토르
# 2    스파이더맨
# Name: 이름, dtype: object

# %%
df.loc[:5,['나이','직업']]
# Out:
#    나이     직업
# 0  58    CEO
# 1  45      신
# 2  18   고등학생
# 3  27     공주
# 4  33  핵물리학자
# 5  25    파일럿

# %%
df.loc[3, '이름']
# Out:
# '원더우먼'

# %%
df.loc[:2, ['이름', '직업']]
# Out:
#       이름    직업
# 0   아이언맨   CEO
# 1     토르     신
# 2  스파이더맨  고등학생

# %%
df.iloc[0:3, [0, 2]]
# Out:
#       이름    직업
# 0   아이언맨   CEO
# 1     토르     신
# 2  스파이더맨  고등학생

# %%
df[df['나이'] >= 50]
# Out:
#      이름  나이   직업  국적    키          재산
# 0  아이언맨  58  CEO  미국  174 11500000000

# %%
df.loc[df['직업'] == '스파이', ['이름', '국적']]
# Out:
#       이름   국적
# 6  블랙위도우  러시아

# %%
# 미션 : 나이가 30초과 and 50 미만인 레코드만 추출

new_df = df[df['나이'] > 30]

new_df[df['나이'] < 50]
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1212\2181445537.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   new_df[df['나이'] < 50]
#       이름  나이     직업     국적    키         재산
# 1     토르  45      신  아스가르드  190        NaN
# 4     헐크  33  핵물리학자     미국  270 1000000000
# 6  블랙위도우  32    스파이    러시아  170   50000000

# %%
df.loc[(df['나이'] > 30) & (df['나이'] < 50)]
# Out:
#       이름  나이     직업     국적    키         재산
# 1     토르  45      신  아스가르드  190        NaN
# 4     헐크  33  핵물리학자     미국  270 1000000000
# 6  블랙위도우  32    스파이    러시아  170   50000000

# %%
# 키가 180 이상인 이름과 나이 컬럼만 출력
# 키가 180 이상인 레코드 출력
# 해당 레코드의 이름, 나이 컬럼만 출력


df.loc[df['키'] > 180 , ['이름', '나이']]
# Out:
#    이름  나이
# 1  토르  45
# 4  헐크  33

# %%
df['국적'] = ''
# Out:
# 0       미국
# 1    아스가르드
# 2       미국
# 3    데미스키라
# 4       미국
# 5       미국
# 6      러시아
# Name: 국적, dtype: object

# %%
df['국적'] == '미국'

type(a)
# Out:
# pandas.core.series.Series

# %%
df['전투력'] = [90,80,20,30,40,60,100]

# %%
df
# Out:
#       이름  나이     직업     국적    키          재산  전투력
# 0   아이언맨  58    CEO     미국  174 11500000000   90
# 1     토르  45      신  아스가르드  190         NaN   80
# 2  스파이더맨  18   고등학생     미국  177         600   20
# 3   원더우먼  27     공주  데미스키라  178         NaN   30
# 4     헐크  33  핵물리학자     미국  270  1000000000   40
# 5   캡틴마블  25    파일럿     미국  170   340000000   60
# 6  블랙위도우  32    스파이    러시아  170    50000000  100

# %%
df['전투력'] = df['전투력'] + 5

# %%
df.rename(columns = { '이름' : '성명' , '직업' : '일' }, inplace=True)

# %%
df
# Out:
#       성명  나이      일     국적    키          재산  전투력
# 0   아이언맨  58    CEO     미국  174 11500000000   95
# 1     토르  45      신  아스가르드  190         NaN   85
# 2  스파이더맨  18   고등학생     미국  177         600   25
# 3   원더우먼  27     공주  데미스키라  178         NaN   35
# 4     헐크  33  핵물리학자     미국  270  1000000000   45
# 5   캡틴마블  25    파일럿     미국  170   340000000   65
# 6  블랙위도우  32    스파이    러시아  170    50000000  105

# %%
df.drop( columns = ['전투력'], inplace=True )

# %%
# 결측치 처리

df[df['재산'].isnull()]
# Out:
#      성명  나이   일     국적    키  재산
# 1    토르  45   신  아스가르드  190 NaN
# 3  원더우먼  27  공주  데미스키라  178 NaN

# %%
df.dropna()
# Out:
#       성명  나이      일   국적    키          재산
# 0   아이언맨  58    CEO   미국  174 11500000000
# 2  스파이더맨  18   고등학생   미국  177         600
# 4     헐크  33  핵물리학자   미국  270  1000000000
# 5   캡틴마블  25    파일럿   미국  170   340000000
# 6  블랙위도우  32    스파이  러시아  170    50000000

# %%
df['재산']  = df['재산'].fillna(df['재산'].mean())

# %%
def add_cm(height):
    return str(height) + 'cm'

df['키'].apply(add_cm)
# Out:
# 0    174cm
# 1    190cm
# 2    177cm
# 3    178cm
# 4    270cm
# 5    170cm
# 6    170cm
# Name: 키, dtype: object

# %%
df.groupby('국적')['나이'].mean()
# Out:
# 국적
# 데미스키라   27
# 러시아     32
# 미국      34
# 아스가르드   45
# Name: 나이, dtype: float64

# %%
# mission
# sales, user both load
# df = sales
# user_df 
# first, loading data

df = pd.read_csv('sales_data.csv')
user_df = pd.read_csv('user_data.csv')

# %%
user_df.head(n=10)
# Out:
#   customer_id customer_name region
# 0        C001           김민준     서울
# 1        C002           이서연     부산
# 2        C003           박도윤     인천
# 3        C004           최지우     서울
# 4        C005           정하은     광주

# %%
df.head()
# Out:
#   customer_id  order_date product_category   amount channel  discount_rate
# 0        C001  2025-09-01               가전  1200000     온라인              0
# 1        C002  2025-09-01             주방용품    45000    오프라인              0
# 2        C003  2025-09-02              식료품    12000     온라인            NaN
# 3        C001  2025-09-02               의류    89000     온라인              0
# 4        C004  2025-09-03             주방용품    21000     온라인              0

# %%
# Out:
#   고객_아이디 고객_이름  지역
# 0   C001   김민준  서울
# 1   C002   이서연  부산
# 2   C003   박도윤  인천
# 3   C004   최지우  서울
# 4   C005   정하은  광주

# %%
# 컬럼명을 한글로 변경
user_df = user_df.rename(columns = {'customer_id' : '고객_아이디', 'customer_name' : '고객_이름', 'region' : '지역'} )
df = df.rename(columns = {'customer_id' : '고객_아이디', 'customer_name' : '고객_이름', 'order_date' : '구매일자', 'product_category' :'제품분류', 'amount':'구매금액', 'channel':'채널', 'discount_rate':'할인률' } )

user_df.head()
df.head()
# Out:
#   고객_아이디        구매일자  제품분류     구매금액    채널  할인률
# 0   C001  2025-09-01    가전  1200000   온라인    0
# 1   C002  2025-09-01  주방용품    45000  오프라인    0
# 2   C003  2025-09-02   식료품    12000   온라인  NaN
# 3   C001  2025-09-02    의류    89000   온라인    0
# 4   C004  2025-09-03  주방용품    21000   온라인    0

# %%
# 구매금액이 10000원 이상인 데이터만 필터링

df[df['구매금액'] > 10000 ]
# Out:
#   고객_아이디        구매일자  제품분류     구매금액    채널  할인률
# 0   C001  2025-09-01    가전  1200000   온라인    0
# 1   C002  2025-09-01  주방용품    45000  오프라인    0
# 2   C003  2025-09-02   식료품    12000   온라인  NaN
# 3   C001  2025-09-02    의류    89000   온라인    0
# 4   C004  2025-09-03  주방용품    21000   온라인    0
# 5   C002  2025-09-03    가전  2500000  오프라인    0
# 7   C003  2025-09-04  주방용품    62000  오프라인  NaN
# 9   C004  2025-09-05    의류   150000   온라인    0

# %%
# '온라인' 채널에서 발생한 구매 중 5000원 이상인 것만 필터링

df[(df['채널'] == '온라인') & (df['구매금액'] >= 5000 )]
# Out:
#   고객_아이디        구매일자  제품분류     구매금액   채널  할인률
# 0   C001  2025-09-01    가전  1200000  온라인    0
# 2   C003  2025-09-02   식료품    12000  온라인  NaN
# 3   C001  2025-09-02    의류    89000  온라인    0
# 4   C004  2025-09-03  주방용품    21000  온라인    0
# 6   C005  2025-09-04    도서     9900  온라인    0
# 8   C001  2025-09-05   식료품     8500  온라인    0
# 9   C004  2025-09-05    의류   150000  온라인    0

# %%
# '가전', '주방용품' 에 속하는 데이터만 필터링
df[(df['제품분류'] == '가전') | (df['제품분류'] == '주방용품')]
# Out:
#   고객_아이디        구매일자  제품분류     구매금액    채널  할인률
# 0   C001  2025-09-01    가전  1200000   온라인    0
# 1   C002  2025-09-01  주방용품    45000  오프라인    0
# 4   C004  2025-09-03  주방용품    21000   온라인    0
# 5   C002  2025-09-03    가전  2500000  오프라인    0
# 7   C003  2025-09-04  주방용품    62000  오프라인  NaN

# %%
# Out:
# 고객_아이디    0
# 구매일자      0
# 제품분류      0
# 구매금액      0
# 채널        0
# 할인률       2
# dtype: int64

# %%
# 각 열별 결측치 개수 확인
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   고객_아이디  10 non-null     object
#  1   구매일자    10 non-null     object
#  2   제품분류    10 non-null     object
#  3   구매금액    10 non-null     int64
#  4   채널      10 non-null     object
#  5   할인률     8 non-null      float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 612.0+ bytes
# 고객_아이디    0
# 구매일자      0
# 제품분류      0
# 구매금액      0
# 채널        0
# 할인률       2
# dtype: int64

# %%
# '고객_아이디', '구매일자', '제품분류', '구매금액', '채널', '할인률'

# %%
# 구매채널별로 그룹화하여, 구매금액의 총합과 평균 동시 구하기
print('------'+' 구매 금액 평균 '+'------')
print(df.groupby('채널')['구매금액'].mean())
print('------'+' 구매 금액 총합 '+'------')
print(df.groupby('채널')['구매금액'].sum())
# Out:
# ------ 구매 금액 평균 ------
# 채널
# 오프라인   869000
# 온라인    212914
# Name: 구매금액, dtype: float64
# ------ 구매 금액 총합 ------
# 채널
# 오프라인    2607000
# 온라인     1490400
# Name: 구매금액, dtype: int64

# %%
df.groupby('채널')['구매금액'].agg(['sum','mean'])
# Out:
#           sum   mean
# 채널
# 오프라인  2607000 869000
# 온라인   1490400 212914

# %%
df.groupby('채널')['구매금액'].agg([sum, 'mean', lambda x: x.max() - x.min(), lambda x: x.max() - x.min() ])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1212\4191162565.py:1: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.groupby('채널')['구매금액'].agg([sum, 'mean', lambda x: x.max() - x.min(), lambda x: x.max() - x.min() ])
#           sum   mean  <lambda_0>  <lambda_1>
# 채널
# 오프라인  2607000 869000     2455000     2455000
# 온라인   1490400 212914     1191500     1191500

# %%
df[['채널','구매금액']]
# Out:
#      채널     구매금액
# 0   온라인  1200000
# 1  오프라인    45000
# 2   온라인    12000
# 3   온라인    89000
# 4   온라인    21000
# 5  오프라인  2500000
# 6   온라인     9900
# 7  오프라인    62000
# 8   온라인     8500
# 9   온라인   150000

# %%
## 결측치가 있는 행 전체 삭제

df.dropna(inplace=True)

# %%
# Out:
#   고객_아이디        구매일자  제품분류     구매금액    채널  할인률
# 0   C001  2025-09-01    가전  1200000   온라인    0
# 1   C002  2025-09-01  주방용품    45000  오프라인    0
# 3   C001  2025-09-02    의류    89000   온라인    0
# 4   C004  2025-09-03  주방용품    21000   온라인    0
# 5   C002  2025-09-03    가전  2500000  오프라인    0
# 6   C005  2025-09-04    도서     9900   온라인    0
# 8   C001  2025-09-05   식료품     8500   온라인    0
# 9   C004  2025-09-05    의류   150000   온라인    0

# %%
df['할인율'].fillna(0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '할인율'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[272], line 1
# ----> 1 df['할인율'].fillna(0, inplace=True)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: '할인율'

# %%
# 할인률이 적용된 df 새롭게 생성
df['실구매금액']  = df['구매금액'] * (1-df['할인률'])

# %%
df
# Out:
#   고객_아이디        구매일자  제품분류     구매금액    채널  할인률      실구매금액
# 0   C001  2025-09-01    가전  1200000   온라인 0.10 1080000.00
# 1   C002  2025-09-01  주방용품    45000  오프라인 0.05   42750.00
# 3   C001  2025-09-02    의류    89000   온라인 0.15   75650.00
# 4   C004  2025-09-03  주방용품    21000   온라인 0.00   21000.00
# 5   C002  2025-09-03    가전  2500000  오프라인 0.05 2375000.00
# 6   C005  2025-09-04    도서     9900   온라인 0.00    9900.00
# 8   C001  2025-09-05   식료품     8500   온라인 0.00    8500.00
# 9   C004  2025-09-05    의류   150000   온라인 0.20  120000.00

# %%
# 고객 등급을 vip와 일반으로 나누기 ( 구매금액 10000 이상이면 )

df['구매금액'].apply(lambda x: 'VIP' if x>=10000 else '일반')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '구매금액'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[338], line 3
#       1 # 고객 등급을 vip와 일반으로 나누기 ( 구매금액 10000 이상이면 )
# ----> 3 df['구매금액'].apply(lambda x: 'VIP' if x>=10000 else '일반')
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: '구매금액'

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
# 제품분류별 구매금액의 평균 구하기
df.groupby('제품분류')['구매금액'].mean()
# Out:
# 제품분류
# 가전     1850000.00
# 도서        9900.00
# 식료품       8500.00
# 의류      119500.00
# 주방용품     33000.00
# Name: 구매금액, dtype: float64

# %%
df.groupby('제품분류')['구매금액'].agg(['mean','sum'])
# Out:
#            mean      sum
# 제품분류
# 가전   1850000.00  3700000
# 도서      9900.00     9900
# 식료품     8500.00     8500
# 의류    119500.00   239000
# 주방용품   33000.00    66000

# %%
merged_df = pd.merge(df, user_df, on = '고객_아이디' )

# %%
merged_df[merged_df['고객_이름'] == '김민준']
# Out:
#   고객_아이디        구매일자 제품분류     구매금액   채널  할인률      실구매금액 고객_이름  지역
# 0   C001  2025-09-01   가전  1200000  온라인 0.10 1080000.00   김민준  서울
# 2   C001  2025-09-02   의류    89000  온라인 0.15   75650.00   김민준  서울
# 6   C001  2025-09-05  식료품     8500  온라인 0.00    8500.00   김민준  서울

# %%
# csv 파일로 저장

merged_df.to_csv('merged_df.csv', index=False, encoding='utf-8')

# %%
# %pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp311-cp311-win_amd64.whl.metadata (52 kB)
#      ---------------------------------------- 0.0/52.8 kB ? eta -:--:--
#      -------------- ----------------------- 20.5/52.8 kB 640.0 kB/s eta 0:00:01
#      -------------------------------------- 52.8/52.8 kB 676.1 kB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp311-cp311-win_amd64.whl.metadata (116 kB)
#      ---------------------------------------- 0.0/116.4 kB ? eta -:--:--
#      -------------------------------------- 116.4/116.4 kB 3.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.0-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.4/8.1 MB 11.8 MB/s eta 0:00:01
#    --- ------------------------------------ 0.8/8.1 MB 9.7 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.2/8.1 MB 10.6 MB/s eta 0:00:01
#    ------- -------------------------------- 1.6/8.1 MB 11.3 MB/s eta 0:00:01
#    --------- ------------------------------ 2.0/8.1 MB 11.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.4/8.1 MB 11.0 MB/s eta 0:00:01
#    ------------- -------------------------- 2.8/8.1 MB 11.3 MB/s eta 0:00:01
#    --------------- ------------------------ 3.1/8.1 MB 11.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.4/8.1 MB 11.0 MB/s eta 0:00:01
#    ------------------ --------------------- 3.9/8.1 MB 10.7 MB/s eta 0:00:01
#    --------------------- ------------------ 4.3/8.1 MB 10.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 11.1 MB/s eta 0:00:01
#    ------------------------- -------------- 5.1/8.1 MB 10.9 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.1 MB 11.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.1 MB 11.2 MB/s eta 0:00:01
#    ------------------------------- -------- 6.4/8.1 MB 11.3 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 11.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.2/8.1 MB 11.2 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  8.0/8.1 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 10.8 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
#    ---------------------------------------- 0.0/225.2 kB ? eta -:--:--
#    --------------------------------------- 225.2/225.2 kB 13.4 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp311-cp311-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------- -------------------------------- 0.4/2.3 MB 13.9 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.3 MB 13.4 MB/s eta 0:00:01
#    --------------------- ------------------ 1.3/2.3 MB 11.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.6/2.3 MB 11.6 MB/s eta 0:00:01
#    ------------------------------------ --- 2.1/2.3 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 10.6 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl (73 kB)
#    ---------------------------------------- 0.0/73.8 kB ? eta -:--:--
#    ---------------------------------------- 73.8/73.8 kB 4.2 MB/s eta 0:00:00
# Downloading pillow-12.1.0-cp311-cp311-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.4/7.0 MB 12.2 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.8/7.0 MB 12.9 MB/s eta 0:00:01
#    ------ --------------------------------- 1.2/7.0 MB 12.7 MB/s eta 0:00:01
#    -------- ------------------------------- 1.6/7.0 MB 11.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.0/7.0 MB 11.7 MB/s eta 0:00:01
#    ------------- -------------------------- 2.4/7.0 MB 11.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.8/7.0 MB 12.0 MB/s eta 0:00:01
#    ------------------ --------------------- 3.2/7.0 MB 11.5 MB/s eta 0:00:01
#    -------------------- ------------------- 3.7/7.0 MB 11.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.1/7.0 MB 11.8 MB/s eta 0:00:01
#    ------------------------- -------------- 4.5/7.0 MB 11.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.9/7.0 MB 11.7 MB/s eta 0:00:01
#    ------------------------------ --------- 5.3/7.0 MB 11.8 MB/s eta 0:00:01
#    -------------------------------- ------- 5.8/7.0 MB 11.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.2/7.0 MB 11.6 MB/s eta 0:00:01
#    ------------------------------------- -- 6.6/7.0 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  7.0/7.0 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 11.2 MB/s eta 0:00:00
# Downloading pyparsing-3.3.1-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.8 kB ? eta -:--:--
#    ---------------------------------------- 121.8/121.8 kB 7.0 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.1.0 pyparsing-3.3.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import pandas as pd

# %%
plt.figure(figsize=(10, 5))
plt.plot([1, 2, 3], [10, 20, 15])
plt.title('간단한 플롯')
plt.show()

# %%
# 선 그래프

plt.plot(x_data, y_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[301], line 3
#       1 # 선 그래프
# ----> 3 plt.plot(x_data, y_data)
#
# NameError: name 'x_data' is not defined

# %%
import matplotlib.pyplot as plt
import pandas as pd
 
# --- 데이터 생성---
data = {
    '월': pd.to_datetime(['2025-01-01', '2025-02-01', '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01']),
    '방문자수': [1500, 1800, 1700, 2100, 2500, 2300]
}
df_line = pd.DataFrame(data)
 
plt.figure(figsize=(10, 6)) # figsize 설정
 
# 1. 플롯 그리기
plt.plot(
    df_line['방문자수'],
    df_line['월'],
    marker='o',
    linestyle='-',
    color='dodgerblue'
)
 
# 2. 그래프 꾸미기 (ax.set_ 대신 plt. 사용)
plt.title('2025년 상반기 월별 웹사이트 방문자 수', fontsize=16)
plt.xlabel('월', fontsize=12)
plt.ylabel('방문자 수 (명)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
 
data = {
    '부서': ['영업1팀', '영업2팀', '마케팅팀', '기술지원팀'],
    '실적(억원)': [12, 15, 8, 5]
}
df_bar = pd.DataFrame(data)
 
plt.figure(figsize=(10, 6))
 
bars = plt.bar(
    df_bar['부서'],
    df_bar['실적(억원)'],
    color=['#FF5733', '#33FF57', '#3357FF', '#FF33A1']
)
 
plt.title('2023년 3분기 부서별 판매 실적', fontsize=16)
plt.xlabel('부서', fontsize=12)
plt.ylabel('실적 (억원)', fontsize=12)
 
# 각 바 위에 실제 값 표시 (plt.text 사용)
for bar in bars:
    yval = bar.get_height()
    # plt.text(x좌표, y좌표, 내용, 정렬방식)
    plt.text(
        bar.get_x() + bar.get_width()/2.0,
        yval,
        f'{yval}억',
        va='bottom',
        ha='center'
    )
 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
 
np.random.seed(42)
advertising_cost = np.random.randint(10, 100, 50)
sales = advertising_cost * 1.5 + np.random.normal(0, 10, 50)
 
plt.figure(figsize=(10, 6))
plt.scatter(
    advertising_cost,
    sales,
    alpha=0.7,
    edgecolors='w',
    s=80
)
 
plt.title('광고비와 매출의 관계', fontsize=16)
plt.xlabel('광고비 (만원)', fontsize=12)
plt.ylabel('매출 (만원)', fontsize=12)
plt.grid(True, linestyle=':', alpha=0.6)
 
plt.show()

# %%
plt.scatter(
    advertising_cost,
    sales,
    c=sales,          # 매출 값에 따라 색상 부여
    cmap='viridis',   # 색상 지도 설정
    alpha=0.8,
    edgecolors='w',
    s=sales * 2       # 매출이 클수록 점도 크게
)
plt.colorbar(label='매출 규모') # 색상 막대 추가

# %%
import matplotlib.pyplot as plt
import numpy as np
 
np.random.seed(0)
customer_ages = np.random.normal(loc=35, scale=10, size=200).astype(int)
 
plt.figure(figsize=(10, 6))
plt.hist(
    customer_ages,
    bins=15,
    color='skyblue',
    edgecolor='black'
)
 
plt.title('고객 연령 분포', fontsize=16)
plt.xlabel('나이', fontsize=12)
plt.ylabel('고객 수 (빈도)', fontsize=12)
 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
 
data = np.random.rand(8, 10)
rows = [f'Row{i+1}' for i in range(data.shape[0])]
cols = [f'Col{i+1}' for i in range(data.shape[1])]
 
plt.figure(figsize=(10, 7))
im = plt.imshow(data, cmap='coolwarm')
plt.colorbar(im)
plt.xticks(np.arange(data.shape[1]), labels=cols)
plt.yticks(np.arange(data.shape[0]), labels=rows)
plt.tick_params(top=True, bottom=False, labeltop=True, labelbottom=False)
plt.setp(plt.gca().get_xticklabels(), rotation=-30, ha="right", rotation_mode="anchor")
 
# 각 셀에 텍스트 추가 (Annotation)
for i in range(data.shape[0]):
    for j in range(data.shape[1]):
        # plt.text(x, y, s) 순서입니다.
        plt.text(j, i, f'{data[i, j]:.2f}',
                 ha="center", va="center", color="w")
 
plt.title("Heatmap using Matplotlib", pad=20)
plt.tight_layout()
plt.show()

# %%
# %pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.4.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ---------------------- ----------------- 163.8/294.9 kB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 4.5 MB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
sns.heatmap(data, annot=True, fmt=".2f")
# Out:
# <Axes: >

# %%
tips = sns.load_dataset('tips')

sns.scatterplot(data=tips, x="total_bill", y="tip", hue="day", s=100)
plt.title("총 결제금액과 팁의 관계 (흡연 여부별)")
plt.show()

# %%
sns.load_dataset('tips')
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 0         16.99 1.01  Female     No   Sun  Dinner     2
# 1         10.34 1.66    Male     No   Sun  Dinner     3
# 2         21.01 3.50    Male     No   Sun  Dinner     3
# 3         23.68 3.31    Male     No   Sun  Dinner     2
# 4         24.59 3.61  Female     No   Sun  Dinner     4
# ..          ...  ...     ...    ...   ...     ...   ...
# 239       29.03 5.92    Male     No   Sat  Dinner     3
# 240       27.18 2.00  Female    Yes   Sat  Dinner     2
# 241       22.67 2.00    Male    Yes   Sat  Dinner     2
# 242       17.82 1.75    Male     No   Sat  Dinner     2
# 243       18.78 3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")
 
# Load the example tips dataset
tips = sns.load_dataset("tips")
 
# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="day", y="total_bill",
            hue="smoker", palette=["m", "g"],
            data=tips)
sns.despine(offset=10, trim=True)

# %%
import seaborn as sns
sns.set_theme(style="ticks")
 
df = sns.load_dataset("tips")
sns.pairplot(df, hue="sex")


plt.show()

# %%
# 제품분류별 매출 비중(Bar Chart) - 어떤 카테고리가 가장 수익이 높은지

# 고객등급별 구매금액 분포 (Box Plot) - VIP와 일반 고객의 구매 단가 차이 확인

# 일자별 매출 추이 (Line Plot) - 시간의 흐름에 따라 매출이 어떻게 변하는지

# 지역별 온라인 주문의 비중



merged_df['총구매금액'] = merged_df.groupby('고객명')['구매금액'].transform('sum')

# %%
import seaborn as sns
sns.set_theme(style="ticks")
sns.pairplot(merged_df, hue="고객_이름")

# %%
sns.scatterplot(data=merged_df, x="", y="", hue="", s=100)
plt.title("총 결제금액과 팁의 관계 (흡연 여부별)")
plt.show()

# %%
merged_df.head()
# Out:
#   고객_아이디        구매일자  제품분류     구매금액    채널  할인률      실구매금액 고객_이름  지역
# 0   C001  2025-09-01    가전  1200000   온라인 0.10 1080000.00   김민준  서울
# 1   C002  2025-09-01  주방용품    45000  오프라인 0.05   42750.00   이서연  부산
# 2   C001  2025-09-02    의류    89000   온라인 0.15   75650.00   김민준  서울
# 3   C004  2025-09-03  주방용품    21000   온라인 0.00   21000.00   최지우  서울
# 4   C002  2025-09-03    가전  2500000  오프라인 0.05 2375000.00   이서연  부산

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="ticks")
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

# %%
# 제품분류별 매출 비중(Bar Chart) - 어떤 카테고리가 가장 수익이 높은지

x = merged_df['제품분류']
y = merged_df['구매금액']
sns.barplot(x=x, y=y, palette="rocket")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1212\3423871066.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x, y=y, palette="rocket")
# <Axes: xlabel='제품분류', ylabel='구매금액'>

# %%
merged_df['등급'] = merged_df['구매금액'].apply(lambda x: 'VIP' if x>=10000 else '일반')
# df['구매금액'].apply(lambda x: 'VIP' if x>=10000 else '일반')

# %%
# 고객등급별 구매금액 분포 (Box Plot) - VIP와 일반 고객의 구매 단가 차이 확인

sns.set_theme(style="ticks", palette="pastel")
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
 
# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="등급", y="구매금액",
            palette=["m", "g"],
            data=merged_df)
sns.despine(offset=10, trim=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1212\2293495962.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="등급", y="구매금액",

# %%
# 일자별 매출 추이 (Line Plot) - 시간의 흐름에 따라 매출이 어떻게 변하는지


sns.set_theme(style="whitegrid")
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

daily = merged_df.groupby('구매일자')['구매금액'].sum().reset_index()

sns.lineplot(data=daily, x='구매일자', y='구매금액', palette="tab10", linewidth= 5)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1212\1324136746.py:10: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=daily, x='구매일자', y='구매금액', palette="tab10", linewidth= 5)
# <Axes: xlabel='구매일자', ylabel='구매금액'>

# %%
# 지역별 온라인 주문의 비중




sns.set_theme(style="whitegrid")
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

daily = merged_df[merged_df.groupby('지역')]

daily
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[365], line 10
#       7 plt.rc('font', family='Malgun Gothic')
#       8 plt.rc('axes', unicode_minus=False)
# ---> 10 daily = merged_df[merged_df.groupby('지역')]
#      12 daily
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6207, in Index._get_indexer_strict(self, key, axis_name)
#    6204     keyarr = com.asarray_tuplesafe(keyarr)
#    6206 if self._index_as_unique:
# -> 6207     indexer = self.get_indexer_for(keyarr)
#    6208     keyarr = self.reindex(keyarr)[0]
#    6209 else:
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6194, in Index.get_indexer_for(self, target)
#    6176 """
#    6177 Guaranteed return of an indexer even when non-unique.
#    6178
#    (...)   6191 array([0, 2])
#    6192 """
#    6193 if self._index_as_unique:
# -> 6194     return self.get_indexer(target)
#    6195 indexer, _ = self.get_indexer_non_unique(target)
#    6196 return indexer
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3960, in Index.get_indexer(self, target, method, limit, tolerance)
#    3955     target = target.astype(dtype, copy=False)
#    3956     return this._get_indexer(
#    3957         target, method=method, limit=limit, tolerance=tolerance
#    3958     )
# -> 3960 return self._get_indexer(target, method, limit, tolerance)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3987, in Index._get_indexer(self, target, method, limit, tolerance)
#    3984     else:
#    3985         tgt_values = target._get_engine_target()
# -> 3987     indexer = self._engine.get_indexer(tgt_values)
#    3989 return ensure_platform_int(indexer)
#
# File pandas/_libs/index.pyx:351, in pandas._libs.index.IndexEngine.get_indexer()
#
# File pandas/_libs/hashtable_class_helper.pxi:7139, in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# TypeError: unhashable type: 'DataFrame'
